# %% [markdown]
# importing all library

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# 1.Sales performance Analysis

# %%
df = pd.read_csv("Amazon Sale Report.csv", encoding="ISO-8859-1")
df.head(10)
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
# 5      5  404-1490984-4578765  04-30-22                       Shipped
# 6      6  408-5748499-6859555  04-30-22                       Shipped
# 7      7  406-7807733-3785945  04-30-22  Shipped - Delivered to Buyer
# 8      8  407-5443024-5233168  04-30-22                     Cancelled
# 9      9  402-4393761-0311520  04-30-22                       Shipped
#
#   Fulfilment Sales Channel ship-service-level  Category Size Courier Status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# ...

# %% [markdown]
# checking Null values

# %%
df.isnull().sum()
print(df)
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128971  128970  406-6001380-7673107  05-31-22                       Shipped
# 128972  128971  402-9551604-7544318  05-31-22                       Shipped
# 128973  128972  407-9547469-3152358  05-31-22                       Shipped
# 128974  128973  402-6184140-0545956  05-31-22                       Shipped
# 128975  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
df_cleaned = df.dropna()
print("\nDataset after Removing Null Values:")
print(df_cleaned.isnull().sum())
# Out:
# Dataset after Removing Null Values:
# index                 0
# Order ID              0
# Date                  0
# Status                0
# Fulfilment            0
# Sales Channel         0
# ship-service-level    0
# Category              0
# Size                  0
# Courier Status        0
# Qty                   0
# currency              0
# Amount                0
# ship-city             0
# ship-state            0
# ship-postal-code      0
# ship-country          0
# B2B                   0
# fulfilled-by          0
# New                   0
# PendingS              0
# dtype: int64

# %%
duplicates = df_cleaned.duplicated().sum()
print(f"\nNumber of Duplicate Rows: {duplicates}")
df_cleaned = df_cleaned.drop_duplicates()
print(f"\nDataset Shape after Removing Duplicates: {df_cleaned.shape}")
# Out:
# Number of Duplicate Rows: 0
#
# Dataset Shape after Removing Duplicates: (0, 21)

# %%
print("\nFinal Cleaned Dataset:")
print(df_cleaned.info())
# Out:
# Final Cleaned Dataset:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               0 non-null      int64
#  1   Order ID            0 non-null      object
#  2   Date                0 non-null      object
#  3   Status              0 non-null      object
#  4   Fulfilment          0 non-null      object
#  5   Sales Channel       0 non-null      object
#  6   ship-service-level  0 non-null      object
#  7   Category            0 non-null      object
#  8   Size                0 non-null      object
#  9   Courier Status      0 non-null      object
#  10  Qty                 0 non-null      int64
#  11  currency            0 non-null      object
#  12  Amount              0 non-null      float64
#  13  ship-city           0 non-null      object
#  14  ship-state          0 non-null      object
# ...

# %%
# Ensure the 'Amount' column is numeric 
df['Amount'] = pd.to_numeric(df['Amount'], errors='coerce')

# %%
# Summary Statistics
print("\nSummary Statistics of Sales Performance:")
sales_stats = {
    "Total Sales Amount Rs": df['Amount'].sum(),
    "Average Sales Amount Rs": df['Amount'].mean(),
    "Median Sales Amount Rs": df['Amount'].median(),
    "Standard Deviation Amount Rs": df['Amount'].std(),
    "Maximum Sales Amount Rs": df['Amount'].max(),
    "Minimum Sales Amount Rs": df['Amount'].min(),
}
for key, value in sales_stats.items():
    print(f"{key}: {value:.2f}")
# Out:
# Summary Statistics of Sales Performance:
# Total Sales Amount Rs: 78590170.25
# Average Sales Amount Rs: 648.56
# Median Sales Amount Rs: 605.00
# Standard Deviation Amount Rs: 281.19
# Maximum Sales Amount Rs: 5584.00
# Minimum Sales Amount Rs: 0.00

# %%
# Sales Over Time 
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
df = df.dropna(subset=['Date'])  # Drop invalid dates 
print(df)
# Aggregate sales by month
df['Month'] = df['Date'].dt.to_period('M')
monthly_sales = df.groupby('Month')['Amount'].sum()
print(monthly_sales)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_17012\3037578840.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
#          index             Order ID       Date                        Status  \
# 0            0  405-8078784-5731545 2022-04-30                     Cancelled
# 1            1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146 2022-04-30                       Shipped
# 3            3  403-9615377-8133951 2022-04-30                     Cancelled
# 4            4  407-1069790-7240320 2022-04-30                       Shipped
# ...        ...                  ...        ...                           ...
# 128971  128970  406-6001380-7673107 2022-05-31                       Shipped
# ...

# %%
# Visualize Sales Trends as a Bar Graph
plt.figure(figsize=(12, 6))
monthly_sales.plot(kind='bar', color='blue', edgecolor='black')
plt.title("Sales Performance Over Time", fontsize=14)
plt.xlabel("Month", fontsize=12)
plt.ylabel("Total Sales", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(["Total Sales"], loc='upper left', fontsize=12)
plt.tight_layout()
plt.show()

# %%
# Sales Distribution
plt.figure(figsize=(10, 5))
plt.hist(df['Amount'], bins=20, color='skyblue', edgecolor='black')
plt.title("Distribution of Sales", fontsize=16)
plt.xlabel("Sales", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(True)
plt.legend()
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_17012\2927306013.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Top 10 Sales Days
top_sales_days = df.nlargest(10, 'Amount')[['Date', 'Amount']]
print("\nTop 10 Sales Days:")
print(top_sales_days)
plt.figure(figsize=(14, 12))
plt.pie(
    top_sales_days['Amount'], 
    labels=top_sales_days['Date'].dt.strftime('%Y-%m-%d'),  # Formatting date labels
    autopct='%1.1f%%', 
    startangle=140, 
    colors=plt.cm.Paired.colors
)
plt.title("Top 10 Sales Days - Distribution", fontsize=16)
plt.legend()
plt.show()
# Out:
# Top 10 Sales Days:
#              Date   Amount
# 42040  2022-04-05  5584.00
# 11161  2022-04-23  5495.00
# 24495  2022-04-16  4235.72
# 89151  2022-05-02  3036.00
# 121226 2022-06-06  2894.00
# 28815  2022-04-13  2864.00
# 39945  2022-04-06  2860.00
# 79900  2022-05-07  2796.00
# 63975  2022-05-19  2698.00
# 75761  2022-05-10  2676.00

# %%
# Using NumPy for Additional Analysis
sales_array = df['Amount'].dropna().values  # Ensure no NaN values in the data

percentiles = {
    "25th Percentile": np.percentile(sales_array, 25),
    "Median (50th Percentile)": np.percentile(sales_array, 50),
    "75th Percentile": np.percentile(sales_array, 75),
    "Variance": np.var(sales_array),
    "Coefficient of Variation": np.std(sales_array) / np.mean(sales_array),
}
print("\nNumPy Analysis:")
for key, value in percentiles.items():
    print(f"{key}: {value:.2f}")
keys = list(percentiles.keys())
values = list(percentiles.values())
if len(values) > 0 and all(np.isfinite(values)):
    plt.figure(figsize=(10, 6))
    bars = plt.bar(keys, values, color=['blue', 'green', 'orange', 'red', 'purple'])

    for bar in bars:
        height = bar.get_height()
        plt.text(
            bar.get_x() + bar.get_width() / 2,
            height,
            f'{height:.2f}',
            ha='center',
            va='bottom',
            fontsize=10
        )

    plt.title("NumPy Analysis of Sales Data", fontsize=16)
    plt.ylabel("Value", fontsize=12)
    plt.xlabel("Metrics", fontsize=12)
    plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for clarity
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.legend(["Key Metrics"], loc='upper right', fontsize=10)

    plt.tight_layout()
    plt.show()
else:
    print("Invalid or insufficient data to plot the bar graph.")
# Out:
# NumPy Analysis:
# 25th Percentile: 449.00
# Median (50th Percentile): 605.00
# 75th Percentile: 788.00
# Variance: 79064.37
# Coefficient of Variation: 0.43

# %%
#  Line Graph of  Sales Performance Over Time
plt.figure(figsize=(12, 6))
monthly_sales.plot(kind='line', marker='o', color='blue', label='Monthly Sales')
plt.title("Sales Performance Over Time", fontsize=16)
plt.xlabel("Month", fontsize=12)
plt.ylabel("Total Sales", fontsize=12)
plt.grid(True)
plt.legend()
plt.show()
# Histogram Distribution of Sales
plt.figure(figsize=(10, 5))
plt.hist(df['Amount'], bins=20, color='skyblue', edgecolor='black')
plt.title("Distribution of Sales", fontsize=16)
plt.xlabel("Sales", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(True)
plt.show()

# Pie Chart Top 10 Sales Days
plt.figure(figsize=(14, 12))
plt.pie(
    top_sales_days['Amount'], 
    labels=top_sales_days['Date'].dt.strftime('%Y-%m-%d'),
    autopct='%1.1f%%', 
    startangle=140, 
    colors=plt.cm.Paired.colors
)
plt.title("Top 10 Sales Days - Distribution", fontsize=16)
plt.legend(loc='upper right', fontsize='8')
plt.show()

# Bar Graph with NumPy Analysis
keys = list(percentiles.keys())
values = list(percentiles.values())
plt.figure(figsize=(10, 6))
bars = plt.bar(keys, values, color=['blue', 'green', 'orange', 'red', 'purple'])
for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        height,
        f'{height:.2f}',
        ha='center',
        va='bottom',
        fontsize=10
    )

# Adding title and labels
plt.title("NumPy Analysis of Sales Data", fontsize=16)
plt.ylabel("Value", fontsize=12)
plt.xlabel("Metrics", fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(["Key Metrics"], loc='upper right', fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# 1.A line graph showing sales trends over months.
# 2.A histogram illustrating the distribution of sales values.
# 3.A pie chart highlighting the top 10 sales days' contributions.
# 4.A bar graph summarizing NumPy-calculated metrics.
