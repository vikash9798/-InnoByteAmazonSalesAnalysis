# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Amazon Sale Report.csv", encoding="ISO-8859-1")
df.head(10)
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
# 5      5  404-1490984-4578765  04-30-22                       Shipped
# 6      6  408-5748499-6859555  04-30-22                       Shipped
# 7      7  406-7807733-3785945  04-30-22  Shipped - Delivered to Buyer
# 8      8  407-5443024-5233168  04-30-22                     Cancelled
# 9      9  402-4393761-0311520  04-30-22                       Shipped
#
#   Fulfilment Sales Channel ship-service-level  Category Size Courier Status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# ...

# %%
df.isnull().sum()
print(df) 
df_cleaned = df.dropna()
print("\nDataset after Removing Null Values:")
print(df_cleaned.isnull().sum()) 
duplicates = df_cleaned.duplicated().sum()
print(f"\nNumber of Duplicate Rows: {duplicates}")
df_cleaned = df_cleaned.drop_duplicates()
print(f"\nDataset Shape after Removing Duplicates: {df_cleaned.shape}")
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128971  128970  406-6001380-7673107  05-31-22                       Shipped
# 128972  128971  402-9551604-7544318  05-31-22                       Shipped
# 128973  128972  407-9547469-3152358  05-31-22                       Shipped
# 128974  128973  402-6184140-0545956  05-31-22                       Shipped
# 128975  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
# Final Cleaned Dataset
print("\nFinal Cleaned Dataset:")
print(df_cleaned.info())
# Out:
# Final Cleaned Dataset:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               0 non-null      int64
#  1   Order ID            0 non-null      object
#  2   Date                0 non-null      object
#  3   Status              0 non-null      object
#  4   Fulfilment          0 non-null      object
#  5   Sales Channel       0 non-null      object
#  6   ship-service-level  0 non-null      object
#  7   Category            0 non-null      object
#  8   Size                0 non-null      object
#  9   Courier Status      0 non-null      object
#  10  Qty                 0 non-null      int64
#  11  currency            0 non-null      object
#  12  Amount              0 non-null      float64
#  13  ship-city           0 non-null      object
#  14  ship-state          0 non-null      object
# ...

# %%
df_cleaned.head(10)
# Out:
# Empty DataFrame
# Columns: [index, Order ID, Date, Status, Fulfilment, Sales Channel, ship-service-level, Category, Size, Courier Status, Qty, currency, Amount, ship-city, ship-state, ship-postal-code, ship-country, B2B, fulfilled-by, New, PendingS]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.head(-10)
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128961  128960  402-0468123-8401109  05-31-22                       Shipped
# 128962  128961  402-0082204-6323568  05-31-22                     Cancelled
# 128963  128962  408-9803724-6565965  05-31-22                     Cancelled
# 128964  128963  404-5963451-7335564  05-31-22                       Shipped
# 128965  128964  404-2225394-8024308  05-31-22                       Shipped
#
# ...

# %%
df.drop('New', inplace=True, axis=1) 
df.drop('PendingS', inplace=True, axis=1)

# %%
df.head(-100)
# Out:
#          index             Order ID        Date                        Status  \
# 0            0  405-8078784-5731545    04-30-22                     Cancelled
# 1            1  171-9198151-1101146    04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146    04-30-22                       Shipped
# 3            3  403-9615377-8133951    04-30-22                     Cancelled
# 4            4  407-1069790-7240320    04-30-22                       Shipped
# ...        ...                  ...         ...                           ...
# 128871  128870  405-7447678-6283558  06-01-2022                       Shipped
# 128872  128871  405-4837393-8997115  06-01-2022                       Shipped
# 128873  128872  405-4724097-1016369  06-01-2022  Shipped - Delivered to Buyer
# 128874  128873  405-4724097-1016369  06-01-2022  Shipped - Delivered to Buyer
# 128875  128874  405-4724097-1016369  06-01-2022  Shipped - Delivered to Buyer
#
# ...

# %%
print("Dataset Columns:", df.columns)
# Out:
# Dataset Columns: Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Qty',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B', 'fulfilled-by'],
#       dtype='object')

# %%
# Order Status Analysis 
status_counts = df['Status'].value_counts(normalize=True) * 100
print("\nProportion of Order Statuses (%):")
print(status_counts)
# Identify problematic statuses
problematic_statuses = ['Cancelled', 'Returned', 'Delayed']  # Define status keywords for problematic cases
df['Problematic'] = df['Status'].apply(lambda x: any(status in x for status in problematic_statuses))

# Calculate proportion of problematic orders
problematic_proportion = df['Problematic'].mean() * 100
print(f"\nProportion of Problematic Orders: {problematic_proportion:.2f}%")

#Courier Status Patterns
courier_status_counts = df['Courier Status'].value_counts()
print("\nCourier Status Patterns:")
print(courier_status_counts)
# Out:
# Proportion of Order Statuses (%):
# Status
# Shipped                          60.332930
# Shipped - Delivered to Buyer     22.295621
# Cancelled                        14.215048
# Shipped - Returned to Seller      1.515011
# Shipped - Picked Up               0.754404
# Pending                           0.510172
# Pending - Waiting for Pick Up     0.217870
# Shipped - Returning to Seller     0.112424
# Shipped - Out for Delivery        0.027137
# Shipped - Rejected by Buyer       0.008529
# Shipping                          0.006203
# Shipped - Lost in Transit         0.003877
# Shipped - Damaged                 0.000775
# Name: proportion, dtype: float64
#
# Proportion of Problematic Orders: 15.73%
#
# Courier Status Patterns:
# Courier Status
# Shipped       109486
# On the Way      6870
# Unshipped       6680
# Cancelled       5940
# Name: count, dtype: int64

# %%
 # Bar Graph Proportion of Order Statuses
plt.figure(figsize=(10, 8))
status_counts.plot(kind='bar', color='orange', edgecolor='black')
plt.title("Proportion of Order Statuses", fontsize=12)
plt.xlabel("Order Status", fontsize=10)
plt.ylabel("Percentage", fontsize=10)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Pie Chart Problematic vs. Non-Problematic Orders
problematic_summary = df['Problematic'].value_counts(normalize=True) * 100
plt.figure(figsize=(12, 8))
plt.pie(
    problematic_summary, 
    labels=['Non-Problematic Orders', 'Problematic Orders'], 
    autopct='%1.1f%%', 
    startangle=140, 
    colors=['green', 'red']
)
plt.title("Proportion of Problematic Orders", fontsize=16)
plt.legend()
plt.show()

# %%
# Bar Graph Courier Status Distribution
plt.figure(figsize=(8, 4))
courier_status_counts.plot(kind='bar', color='blue', edgecolor='black')
plt.title("Courier Status Distribution", fontsize=16)
plt.xlabel("Courier Status", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
#  Histogram Distribution of Amounts for Problematic Orders
problematic_orders = df[df['Problematic']]
plt.figure(figsize=(10, 6))
plt.hist(problematic_orders['Amount'], bins=20, color='purple', edgecolor='black')
plt.title("Distribution of Amounts for Problematic Orders", fontsize=16)
plt.xlabel("Amount", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
print("\nStatistics for Problematic Orders:")
print(problematic_orders['Amount'].describe())
# Out:
# Statistics for Problematic Orders:
# count    12714.000000
# mean       644.086932
# std        264.960483
# min          0.000000
# 25%        442.000000
# 50%        605.000000
# 75%        771.000000
# max       4235.720000
# Name: Amount, dtype: float64
